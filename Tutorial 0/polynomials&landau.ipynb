# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import root_scalar

# %%
def p(x):
    return x**4 - 4*x**3

# %%
def dpdx(x):
    return 4*x**3 - 12*x**2
def dpdx2(x):
    return 12*x**2 - 24*x

# %%
root1 = root_scalar(p, bracket=[-1, 1])
root1
# Out:
#       converged: False
#            flag: convergence error
#  function_calls: 102
#      iterations: 100
#            root: 4.052006419776338e-11
#          method: brentq

# %%
root2 = root_scalar(p, bracket=[3, 5])
root2
# Out:
#       converged: True
#            flag: converged
#  function_calls: 10
#      iterations: 9
#            root: 4.0
#          method: brentq
